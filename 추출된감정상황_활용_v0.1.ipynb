# %%
import import_ipynb
# gpt를 api로 가져옴
from API import feelsitu
import pandas as pd

# %%
melon = pd.read_csv('노래_분류.csv')
melon.head(10)
# Out:
#    순번                                     제목                 가수  \
# 0   1                              LOVE DIVE          IVE (아이브)
# 1   2                                 TOMBOY            (여자)아이들
# 2   3                                   취중고백         김민석 (멜로망스)
# 3   4                                 사랑인가 봐               멜로망스
# 4   5                              사랑은 늘 도망가                임영웅
# 5   6                                 ELEVEN          IVE (아이브)
# 6   7                   봄여름가을겨울 (Still Life)       BIGBANG (빅뱅)
# 7   8                          다정히 내 이름을 부르면          경서예지, 전건호
# 8   9  That That (prod. & feat. SUGA of BTS)           싸이 (PSY)
# 9  10                   정이라고 하자 (Feat. 10CM)  BIG Naughty (서동현)
#
#                                                   가사  감정  상황
# 0  네가 참 궁금해 그건 너도 마찬가지 이거면 충분해 쫓고 쫓는 이런 놀이 참을 수 없...  기쁨  운동
# 1  Look at you 넌 못 감당해 날 Ya took off hook 기분은 Cok...  기쁨  운동
# 2  뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구들...  기쁨  운동
# ...

# %%
text = input("텍스트 입력 : ")
feel,situ = feelsitu(text)
# Out:
# 텍스트 입력 : 피크닉
# 감정 : 편안함, 행복, 놀람
# 상황 : 여행, 날씨

# %%
result_feel = []
result_feel = melon[melon['감정']==feel]
#result_feel.head()
if len(result_feel) != 0:
  print(result_feel['제목']+' '+result_feel['가수'])
else:
  print('이 감정에 해당하는 노래는 없습니다.')
# Out:
# 이 감정에 해당하는 노래는 없습니다.

# %%
result_situ = []
result_situ = melon[melon['상황']==situ]
result_situ.head()

if len(result_situ) != 0:
  print(result_situ['제목']+' '+result_situ['가수'])
else:
  print('이 상황에 해당하는 노래는 없습니다.')
# Out:
# 36    언제나 사랑해 케이시 (Kassy)
# dtype: object

# %%
melon[melon['제목']=='언제나 사랑해']
# Out:
#     순번       제목           가수  \
# 36  37  언제나 사랑해  케이시 (Kassy)
#
#                                                    가사      감정      상황
# 36  둘이 손잡고 걸을 때 마주 보며 또 웃을 때 사랑한다 말하지 않아도 알아 널 만나러...  설렘, 행복  여행, 날씨
